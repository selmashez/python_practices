# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('1.png')
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[173, 173, 173],
#         [173, 173, 173],
#         [173, 173, 173],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[173, 173, 173],
#         [173, 173, 173],
#         [173, 173, 173],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[173, 173, 173],
#         [173, 173, 173],
#         [172, 172, 172],
# ...

# %%
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
def stippling_image(image, num_points=100000, dot_size=4, threshold=0.5):
    height, width = image.shape

    stippled_image = np.ones((height, width), dtype=np.uint8) * 255

    normalized_image = (255 - image) / 255.0 

    normalized_image[normalized_image < threshold] = 0  
    normalized_image[normalized_image >= threshold] = 1  

    for _ in range(num_points):
        x = np.random.randint(0, width)
        y = np.random.randint(0, height)

        if np.random.rand() < normalized_image[y, x]:  
            cv2.circle(stippled_image, (x, y), dot_size, 0, -1)

    return stippled_image

stippled_image = stippling_image(image, num_points = 100000, dot_size =4,threshold= 0.5)

plt.imshow(stippled_image)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 20
#      16             cv2.circle(stippled_image, (x, y), dot_size, 0, -1)
#      18     return stippled_image
# ---> 20 stippled_image = stippling_image(image, num_points = 100000, dot_size =4,threshold= 0.5)
#      22 plt.imshow(stippled_image)
#      23 plt.axis('off')
#
# Cell In[41], line 2, in stippling_image(image, num_points, dot_size, threshold)
#       1 def stippling_image(image, num_points=100000, dot_size=4, threshold=0.5):
# ----> 2     height, width = image.shape
#       4     stippled_image = np.ones((height, width), dtype=np.uint8) * 255
#       6     normalized_image = (255 - image) / 255.0
#
# ValueError: too many values to unpack (expected 2)

# %%
def stippling_image(image, num_points=100000, dot_size=4, threshold=0.5):
    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    height, width = image.shape
    stippled_image = np.ones((height, width), dtype=np.uint8) * 255

    normalized_image = (255 - image) / 255.0
    normalized_image[normalized_image < threshold] = 0
    normalized_image[normalized_image >= threshold] = 1

    for _ in range(num_points):
        x = np.random.randint(0, width)
        y = np.random.randint(0, height)

        if np.random.rand() < normalized_image[y, x]:
            cv2.circle(stippled_image, (x, y), dot_size, 0, -1)

    return stippled_image

image = cv2.imread('1.png')
stippled_image = stippling_image(image, num_points=100000, dot_size=4, threshold=0.5)

plt.imshow(stippled_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
def stippling_image(image, num_points=100000, dot_size=4, threshold=0.5):
    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    height, width = image.shape
    stippled_image = np.ones((height, width), dtype=np.uint8) * 255

    normalized_image = (255 - image) / 255.0
    normalized_image[normalized_image < threshold] = 0
    normalized_image[normalized_image >= threshold] = 1

    for _ in range(num_points):
        x = np.random.randint(0, width)
        y = np.random.randint(0, height)

        if np.random.rand() < normalized_image[y, x]:
            cv2.circle(stippled_image, (x, y), dot_size, 0, -1)

    return stippled_image

image = cv2.imread('1.png')
stippled_image = stippling_image(image, num_points=200000, dot_size=6, threshold=0.5)

plt.imshow(stippled_image, cmap='gray')
plt.axis('off')
plt.show()
